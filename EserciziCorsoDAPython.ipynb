# %% [markdown]
# # Data Analysis with Python (Exercises)

# %%
import pandas as pd
df = pd.read_csv("bestsellers.csv")

# %%
df

# %% [markdown]
# Parte 1

# %%
# find lowest user rating in the DF
df["price"].min()

# %%
# find the highest price in the DF
df["price"].max()

# %% [markdown]
# Parte 2

# %%
# What is the average user rting in the first 5 rows
df.head(5).max()

# %%
# what appeared the most? 
df.mode()

# %% [markdown]
# Parte 3

# %%
# what is the total sum of values? 
df.sum(numeric_only = True)

# %%
# how many different authors are featuredd in the dataset
df.count()

# %%
# which autor wrote the most number of books on the list? how many did  they write ? 
df.describe(include= ["object"])

# %% [markdown]
# #04 Exercise - series / columns / plot() basics

# %%
# trova la colonna
df["price"]

# %%
# trova le prime 8 righe di una colonna
df["author"].head(8)

# %% [markdown]
# Parte 2

# %%
# trova il genere unico
df["author"].unique()

# %%
# trova il numero di genere unico
df["author"].nunique()

# %%
# trova il average prezzo
df["price"].mean()

# %%
# Trova i prezzi piu alti 
df["price"].nlargest(10)

# %% [markdown]
# Parte 3

# %%
# trova i 3 piu comuni titoli 
df["title"].value_counts()

# %%
# crea un data frame con autori e user ratings
df[["author", "rank"]]

# %%
# col nuovo df trova la combinazione piu comune
df.value_counts().head()

# %% [markdown]
# Parte 4

# %%
# crea un grafico a torta dei generi totali che appaiono (userò rank)
df["rank"].head(5).value_counts().plot(kind = "pie")

# %%
# trova top 10 authori e plotta i numeri dei libri usando "bar"
df["author"].value_counts(10).head(5).plot(kind= "bar")

# %%
# BONUS: Histogramm di user reviews (Cerca nel database di pandas.series.plot)
df["rank"].plot(kind= "hist")
